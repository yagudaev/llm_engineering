# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can create high-quality content such as:
#  * Articles, blog posts, and social media updates
#  * Product descriptions and marketing materials
#  * Advertisements and promotional videos
#  * Automated content suggestion tools for websites and blogs
# 2. **Design and Visual Content**: Generative AI can generate:
#  * Customized logos, icons, and graphics
#  * Unique product designs and packaging ideas
#  * Artistic paintings, illustrations, and photographs
#  * Fashion designs and outfit suggestions
# 3. **Music and Audio Generation**: Generative AI can create:
#  * Original music tracks and sound effects
#  * Automated audio loops and beats for music productions
#  * Podcast and video intro/outro themes and music tracks
# 4. **Chatbots and Virtual Assistants**: Generative AI can power:
#  * Advanced chatbots that understand context and intent
#  * Personalized customer service and support tools
#  * Virtual assistants for scheduling, reminders, and to-do lists
# 5. **Marketing and Advertising**: Generative AI can help with:
#  * Automated ad creative generation (e.g., images, videos)
#  * Personalized marketing messages and offers
#  * Predictive analytics and lead scoring
# 6. **Product Development and Design**: Generative AI can aid in:
#  * Rapid prototyping and testing of new products
#  * Designing custom furniture, appliances, and consumer goods
#  * Creating 3D models for architectural and product visualization
# 7. **Education and Training**: Generative AI can generate:
#  * Personalized learning materials and courses
#  * Automated test questions and grading tools
#  * Real-time feedback and coaching systems
# 8. **Healthcare and Medical Research**: Generative AI can help with:
#  * Analyzing medical images (e.g., X-rays, MRIs) for diagnosis
#  * Generating personalized treatment plans and medication regimens
#  * Developing new treatments and therapies based on data analysis
# 9. **Supply Chain Management**: Generative AI can optimize:
#  * Supply chain logistics and transportation management
#  * Demand forecasting and inventory optimization
#  * Predictive maintenance and quality control
# 10. **Financial Services and Insurance**: Generative AI can aid in:
#  * Risk assessment and credit scoring
#  * Automated portfolio management and investment analysis
#  * Generating customized insurance policies and quotes
#
# These examples illustrate the vast potential of Generative AI to transform various industries and business processes, enabling organizations to create new revenue streams, improve efficiency, and deliver better customer experiences.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI (Artificial Intelligence) has numerous business applications across various industries, including:
#
# 1. **Content Generation**: AI can generate high-quality content such as articles, blog posts, social media posts, and even entire books. This can save time and resources for businesses that need to produce large amounts of content.
# 2. **Chatbots and Virtual Assistants**: Generative AI-powered chatbots can engage with customers, provide support, and answer frequently asked questions. Virtual assistants like Siri, Alexa, and Google Assistant use similar technology to provide personalized experiences.
# 3. **Product Design and Development**: Generative AI can be used to design and develop new products, such as 3D models, prototypes, and even entire product lines. This can accelerate the product development process and reduce costs.
# 4. **Marketing Automation**: AI can analyze customer data and generate personalized marketing campaigns, offers, and content to improve engagement and conversion rates.
# 5. **Data Analysis and Visualization**: Generative AI can help analyze and visualize large datasets, identifying patterns and insights that may not be apparent through human analysis alone.
# 6. **Predictive Maintenance**: AI-powered predictive maintenance can analyze sensor data from machines and equipment to predict when maintenance is required, reducing downtime and improving overall efficiency.
# 7. **Personalization**: Generative AI can help personalize customer experiences by analyzing user behavior, preferences, and demographics to provide tailored recommendations and offers.
# 8. **Innovation and R&D**: Generative AI can be used to explore new ideas, generate hypotheses, and even discover new compounds for pharmaceutical applications.
# 9. **Customer Service**: AI-powered chatbots and virtual assistants can help resolve customer complaints, answer questions, and provide support in real-time.
# 10. **Creative Writing**: Generative AI can assist writers with generating ideas, outlines, and even entire drafts of content, such as articles, stories, or even scripts.
#
# Some specific business use cases for Generative AI include:
#
# * **Fashion brands**: using AI to generate new product designs, styles, and patterns
# * **Retailers**: using AI-powered chatbots to help customers with purchases and returns
# * **Financial institutions**: using AI to analyze financial data and identify potential risks and opportunities
# * **Healthcare providers**: using AI to analyze patient data and develop personalized treatment plans
# * **Manufacturers**: using AI to optimize production processes, predict maintenance needs, and improve product quality.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative use cases across various industries.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can be used to create high-quality, customized content such as:
#  * Blog posts and articles
#  * Social media posts and tweets
#  * Product descriptions and product images
#  * Book chapters and eBooks
# 2. **Graphic Design**: Generative AI can generate visual content such as:
#  * Logos and branding materials
#  * Infographics
#  * Image descriptions for visually impaired individuals
# 3. **Marketing Automation**: Generative AI can be used to automate marketing tasks, such as:
#  * Personalized email templates
#  * Automated social media posts
#  * Lead generation and qualification
# 4. **Product Development**: Generative AI can assist in product development by generating:
#  * New product designs and prototypes
#  * Alternative product concepts
#  * Predictive model predictions for demand and supply
# 5. **Customer Service Automation**: Generative AI can be used to automate customer service tasks, such as:
#  * Chatbots and virtual assistants
#  * Automated customer support responses
# 6. **Data Analysis**: Generative AI can help analyze and visualize complex data sets, enabling companies to gain insights into their operations and make data-driven decisions.
# 7. **Speech Recognition**: Generative AI can be used in speech recognition technology, which enables:
#  * Voice-controlled assistants and virtual keyboards
#  * Speech-to-text transcription services
# 8. **Music Composition**: Generative AI can be used by music producers to generate new music or improve existing compositions, creating unique sounds and styles.
# 9. **Medical Imaging Analysis**: Generative AI can help analyze medical images, enabling the detection of diseases at an early stage.
# 10. **Virtual Reality (VR) and Augmented Reality (AR)**: Generative AI can be used to create highly detailed and realistic virtual environments and objects for VR/AR applications.
#
# Business benefits of generative AI include:
#
# * Increased efficiency and productivity
# * Improved accuracy and precision
# * Enhanced creativity and innovation
# * Reduced costs and costs savings
# * Ability to adapt rapidly to changing markets and trends

# %% [markdown]
# ## Are you confused about why that works?
#
# It seems strange, right? We just used OpenAI code to call Ollama?? What's going on?!
#
# Here's the scoop:
#
# The python class `OpenAI` is simply code written by OpenAI engineers that makes calls over the internet to an endpoint.
#
# When you call `openai.chat.completions.create()`, this python code just makes a web request to the following url: "https://api.openai.com/v1/chat/completions"
#
# Code like this is known as a "client library" - it's just wrapper code that runs on your machine to make web requests. The actual power of GPT is running on OpenAI's cloud behind this API, not on your computer!
#
# OpenAI was so popular, that lots of other AI providers provided identical web endpoints, so you could use the same approach.
#
# So Ollama has an endpoint running on your local box at http://localhost:11434/v1/chat/completions
# And in week 2 we'll discover that lots of other providers do this too, including Gemini and DeepSeek.
#
# And then the team at OpenAI had a great idea: they can extend their client library so you can specify a different 'base url', and use their library to call any compatible API.
#
# That's it!
#
# So when you say: `ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')`
# Then this will make the same endpoint calls, but to Ollama instead of OpenAI.

# %% [markdown]
# ## Also trying the amazing reasoning model DeepSeek
#
# Here we use the version of DeepSeek-reasoner that's been distilled to 1.5B.
# This is actually a 1.5B variant of Qwen that has been fine-tuned using synethic data generated by Deepseek R1.
#
# Other sizes of DeepSeek are [here](https://ollama.com/library/deepseek-r1) all the way up to the full 671B parameter version, which would use up 404GB of your drive and is far too large for most!

# %%
# !ollama pull deepseek-r1:1.5b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling aabd4debf0c8: 100% ▕██████████████████▏ 1.1 GB
# pulling c5ad996bda6e: 100% ▕██████████████████▏  556 B
# pulling 6e4c38e1172f: 100% ▕██████████████████▏ 1.1 KB
# pulling f4d24e9138dd: 100% ▕██████████████████▏  148 B
# pulling a85fe2a2e58e: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)
# Out:
# <think>
# Okay, so I need to explain the key concepts behind Large Language Models (LLMs), focusing on how they use neural networks, attention, and transformers. Hmm, where do I start? I know that LLMs are AI models that can generate text, like ChatGPT or openAI's GPT-3. They must rely on some complex components to process and understand language.
#
# First, the neural network part. Neural networks are inspired by the human brain's structure, right? They have layers of nodes processing information. I remember something about multiple hidden layers learning representations from various features. Maybe in LLMs, these help models capture different levels of meaning. But wait, how do they work exactly with language processing?
#
# Then there's attention. I think attention allows models to focus on specific parts of the input text when making a prediction or generating output. It's about assigning importance weights to input signals. I recall something about self-attention in Transformers—I'm not sure yet.
#
# The transformer model is called that because it uses multi-head attention, which seems different from regular RNNs. Unlike RNNs, transformers don't have loops, so they can handle variable length sequences better efficiently. They process tokens one by one, each handling its output to form the final representation.
#
# Putting it all together, maybe LLMs use neural networks to model the probability distributions of their outputs, attention for focusing on relevant parts, and transformers for efficient, sequence-wise processing. It must train through supervised or unsupervised learning from examples. But how exactly does this fit into text generation? I think each token's prediction is made with some context from previous tokens, using attention to prioritize those.
#
# Wait, in Transformers, attention is distributed across input sequences. So when predicting a new word, the model attends to all context words by looking at their embeddings through multiple heads. Each head computes its own focused representation and combines them probabilistically. That makes sense for capturing complex relationships between words. The self-looping nature of the architecture allows training with low computational resources.
#
# But why do these components work together? Like how does the transformer's attention mechanism interact with neural networks in LLMs? Maybe each layer in the transformer applies a series of transformations, while attention within a decoder or encoder module helps focus on relevant tokens. It all boils down to processing language through structured modules that understand sequences.
#
# Alright, I think I have a rough understanding now. The neural network captures word meanings and context through hidden layers. Attention allows the model to selectively pay attention to important tokens during prediction or generation. Transformers process sequential data efficiently using self-attention across all time steps, allowing models like GPT-3 to become incredibly powerful in capturing long-range dependencies by leveraging distributed learning across multiple heads.
# </think>
#
# Large Language Models (LLMs) are advanced AI systems designed to generate human-level text through complex computational models. Here's an organized overview of the key components that underpin these models, focusing on neural networks, attention, and transformers:
#
# 1. **Neural Networks**:
#    - LLMs utilize multi-layered neural networks inspired by biological neurons. These networks process input data by learning hierarchical representations, capturing intricate features through multiple hidden layers.
#    - They are sensitive to the structure of patterns in text and can model the probability distributions of outputs, enabling accurate predictions.
#
# 2. **Attention**:
#    - Attention mechanisms allow models to focus on specific parts of input data during sequence processing. Each node assigns importance weights based on its relevance, enhancing understanding for tasks like translation.
#    - This is particularly useful when tokens need to be prioritized based on their contextual significance.
#
# 3. **Transformers**:
#    - Transformers are a component in LLMs that process sequences efficiently. They use self-attention across all time steps, enabling dynamic and distributed learning by multiple heads working together.
#    - The model's unique architecture allows it to handle variable-length input sequences effectively with low computational resources.
#
# 4. **Training Components**:
#    - All components learn through supervised or unsupervised methods during training. LLMs maintain stable performance even after losing some architectural details, crucial for text generation tasks.
#    - Through this training, the model learns to encode, decode, and generate text based on contextual dependencies, making them versatile in various applications.
#
# In summary, LLMs combine neural networks' ability to capture word meanings via hidden layers, attention's focus mechanism during processing, and transformers' efficient sequence handling. These components work together using distributed learning across multiple heads to capture complex relationships and long-range dependencies effectively.

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.

# %%
def fetch_webpage(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    title = soup.title.string if soup.title else "No title"
    text = soup.get_text()

    return {"title": title, "text": text}


result = fetch_webpage("https://www.yagudaev.com")
print(f"Title: {result['title']}")
print(f"Text preview: {result['text'][:200]}...")

# def summarize_webpage(url):
# 	# call llm
# Out:
# Title: Michael Yagudaev - Posts | Michael Yagudaev
# Text preview: Michael Yagudaev - Posts | Michael YagudaevNew Project!  🎧 Listen to any text as audiobook-quality soundTry it nowMichael YagudaevPostsTalksProjectsAboutContactPosts#AI#Animation#AudiowaveAI#Augmented...

# %%
def summarize_webpage(url):
	result = fetch_webpage(url)
	title = result['title']
	text = result['text']

	messages = [
		{
			"role": "system",
			"content": """
				You are a helpful assistant that summarizes webpages. You will be given a title and text of a webpage.
				You will need to summarize the webpage in a few sentences. Respond in markdown format."""
		},
		{
			"role": "user",
			"content": f"Title: {title}\n\nText: {text}"
		}
	]

	# call llm
	response = ollama.chat(model=MODEL, messages=messages)
	return response['message']['content']


summary = summarize_webpage("https://www.yagudaev.com")
print(summary)
# Out:
# # Summary of Michael Yagudaev's Posts
#
# Michael Yagudaev is a developer who shares his experiences, projects, and knowledge on various topics related to software development, AI, and web design. He writes about building products, testing tools, and automating tasks.
#
# ## Notable Projects
#
# * AudiowaveAI: transforms text into natural-sounding audio
# * CreativeFlow: animates Figma designs into marketing videos
# * Conceptual: automates image generation using Figma
#
# ## Trends and Insights
#
# * The importance of testing on mobile devices and using Cypress.io
# * The evolution of AR technology and its applications in software development
# * The challenges of building sticky products users love with Google Chrome
# * The benefits of using SnippetSky to store, manage, and share code snippets
